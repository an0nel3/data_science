# %%
import csv as csv
import numpy as np
import time,timeit
from scipy.optimize import curve_fit
import pandas as pd
import matplotlib.pyplot as plt

repairs = pd.read_csv('RepairTrain.csv')

# %%
def month_and_years(df,column):
    years = []
    months = []
    ym_sale = pd.to_datetime(df[column])
    for each_tuple in ym_sale:
        years.append(each_tuple.year)
        months.append(each_tuple.month)
    return years,months
year_sale,month_sale = month_and_years(repairs,"year/month(sale)")
year_repair,month_repair = month_and_years(repairs,"year/month(repair)")

# %%
data_frame = repairs[['module_category','component_category','number_repair']]
#data_frame['year_sale'] = year_sale
#data_frame['month_sale'] = month_sale
data_frame['year'] = year_repair
data_frame['month'] = month_repair
df       = data_frame.groupby(['module_category','component_category','year','month', \
                               ],as_index = False)
df_mod   = df.sum()

# %%
df_mod.to_csv('modded.csv',index=False,header=True, sep=',')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-130-539667f75546> in <module>()
# ----> 1 df_mod.to_csv('modded.csv',index=False,header=True, sep=',')
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, cols, header, index, index_label, mode, nanRep, encoding, quoting, line_terminator, chunksize, tupleize_cols, **kwds)
#    1408                                      chunksize=chunksize,engine=kwds.get("engine"),
#    1409                                      tupleize_cols=tupleize_cols)
# -> 1410         formatter.save()
#    1411
#    1412     def to_excel(self, excel_writer, sheet_name='sheet1', na_rep='',
#
# C:\Anaconda\lib\site-packages\pandas\core\format.pyc in save(self)
#     950             close = False
#     951         else:
# --> 952             f = com._get_handle(self.path_or_buf, self.mode, encoding=self.encoding)
#     953             close = True
#     954
#
# C:\Anaconda\lib\site-packages\pandas\core\common.pyc in _get_handle(path, mode, encoding, compression)
#    1728             f = open(path, mode, errors='replace')
#    1729     else:
# -> 1730         f = open(path, mode)
#    1731     return f
#    1732
#
# IOError: [Errno 13] Permission denied: 'modded.csv'

# %%
def modded(data):
    mods = data['module_category'].unique()
    
    max_year = data['year'].max()
    data['time'] = 12*(data['year']-max_year)+data['month']
    return data

# %%
def gauss(x, *p):
    A, mu, sigma = p
    
    #print x
    #print "\n"
    #print type(x)
   # arg = len(x)
    yes  = A*np.exp(-(x-mu)**2/(2.*sigma**2))
    
    print A
    return yes
    
def model_returner(train):    
    models = {}
    train = modded(train)
    mods = train['module_category'].unique()
    #print mods
    for each_mod in mods:
        cats = train[train['module_category']==each_mod]['component_category'].unique()
        for each_cat in cats:
            #print each_mod
            #print each_cat
            new_data = train[(train['module_category']==each_mod) \
                    & (train['component_category']==each_cat)]
            
            coeff, var_matrix = curve_fit(gauss, new_data['time'],\
                            new_data['number_repair'],p0=p0)
            models[(each_mod,each_cat)] = coeff
            #print models
    return models
mine = model_returner(df_mod)
# Out:
# 1.0
# 1.0
# 1.0
# 1.0000000149
# 1.0
# 1.0
# 0.824168705059
# 0.82416871734
# 0.824168705059
# 0.824168705059
# 1.74679890538
# 1.74679893141
# 1.74679890538
# 1.74679890538
# 3.55295561561
# 3.55295566856
# 3.55295561561
# 3.55295561561
# 7.8143474226
# 5.3560167684
# 5.35601684821
# 5.3560167684
# 5.3560167684
# 7.96193782496
# 6.29794683205
# 6.29794692589
# 6.29794683205
# 6.29794683205
# 7.73510989657
# 7.73511001183
# 7.73510989657
# 7.73510989657
# 11.0299238208
# 11.0299239851
# 11.0299238208
# 11.0299238208
# 11.5473277741
# 11.5473279461
# 11.5473277741
# 11.5473277741
# 11.6038832999
# 11.6038834728
# 11.6038832999
# 11.6038832999
0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-3dc6fee8c4ae> in <module>()
#      27             #print models
#      28     return models
# ---> 29 mine = model_returner(df_mod)
#
# <ipython-input-163-3dc6fee8c4ae> in model_returner(train)
#      23             new_data = train[(train['module_category']==each_mod)                     & (train['component_category']==each_cat)]
#      24
# ---> 25             coeff, var_matrix = curve_fit(gauss, new_data['time'],                            new_data['number_repair'],p0=p0)
#      26             models[(each_mod,each_cat)] = coeff
#      27             #print models
#
# C:\Anaconda\lib\site-packages\scipy\optimize\minpack.pyc in curve_fit(f, xdata, ydata, p0, sigma, **kw)
#     531     # Remove full_output from kw, otherwise we're passing it in twice.
#     532     return_full = kw.pop('full_output', False)
# --> 533     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     534     (popt, pcov, infodict, errmsg, ier) = res
#     535
#
# C:\Anaconda\lib\site-packages\scipy\optimize\minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     369     m = shape[0]
#     370     if n > m:
# --> 371         raise TypeError('Improper input: N=%s must not exceed M=%s' % (n, m))
#     372     if epsfcn is None:
#     373         epsfcn = finfo(dtype).eps
#
# TypeError: Improper input: N=3 must not exceed M=1
# 6.25332285433
# 6.25332294751
# 6.25332285433
# 6.25332285433
# 13.4619762819
# 13.4619764825
# 13.4619762819
# 13.4619762819
# 14.7198265757
# 14.7198267951
# 14.7198265757
# 14.7198265757
# 17.1683407675
# 17.1683410234
# 17.1683407675
# 17.1683407675
# 17.3011215214
# 17.3011217792
# 17.3011215214
# 17.3011215214
# 17.2933967743
# 17.293397032
# 17.2933967743
# 17.2933967743
# 17.2957403708
# 17.2957406286
# 17.2957403708
# 17.2957403708
# 17.2956939647
# 17.2956939647
# 1.0

# %%
mapper = pd.read_csv('Output_TargetID_Mapping.csv')
mapper=modded(mapper)

# %%
arrays = mapper.values

# %%
arrays.shape[0]

# %%
arrays[4255]

# %%
row = arrays[0,:]
row

# %%
def predictions(models):
    mapper = pd.read_csv('Output_TargetID_Mapping.csv')
    preds = []
    mapper = modded(mapper)
    arrays = mapper.values
    num_rows = arrays.shape[0]
    for i in xrange(num_rows):
        mod = arrays[0]
        cat = arrays[1]
        x_val = arrays[-1]
        A, mu, sigma = models[(mod,cat)] 
        prediction = A*np.exp(-(x_val-mu)**2/(2.*sigma**2))
        preds.append(prediction)
    
    assert len(preds) == num_rows
    return preds

# %%
df_mod[df_mod['module_category']=="M1"]['component_category'].unique()

# %%
new_data = df_mod[(df_mod['module_category']=="M1") \
                    & (df_mod['component_category']=='P10')]
coeff, var_matrix = curve_fit(gauss,2,2,p0=p0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-40b37158a3f3> in <module>()
#       1 new_data = df_mod[(df_mod['module_category']=="M1")                     & (df_mod['component_category']=='P10')]
# ----> 2 coeff, var_matrix = curve_fit(gauss,2,2,p0=p0)
#
# C:\Anaconda\lib\site-packages\scipy\optimize\minpack.pyc in curve_fit(f, xdata, ydata, p0, sigma, **kw)
#     531     # Remove full_output from kw, otherwise we're passing it in twice.
#     532     return_full = kw.pop('full_output', False)
# --> 533     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     534     (popt, pcov, infodict, errmsg, ier) = res
#     535
#
# C:\Anaconda\lib\site-packages\scipy\optimize\minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     369     m = shape[0]
#     370     if n > m:
# --> 371         raise TypeError('Improper input: N=%s must not exceed M=%s' % (n, m))
#     372     if epsfcn is None:
#     373         epsfcn = finfo(dtype).eps
#
# TypeError: Improper input: N=3 must not exceed M=1
# 1.0
